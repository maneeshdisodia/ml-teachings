# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import make_blobs

# %%
X,y= make_blobs(n_samples=200,n_features=2,centers=4,cluster_std=1.8,random_state=101)

# %%
X.shape
# Out:
# (200, 2)

# %%
type(X)
# Out:
# numpy.ndarray

# %%
y
# Out:
# array([3, 2, 0, 2, 2, 1, 2, 0, 2, 0, 3, 0, 2, 2, 3, 0, 2, 0, 1, 3, 1, 0, 0,
#        1, 3, 1, 1, 0, 2, 2, 3, 1, 2, 0, 0, 3, 1, 1, 1, 2, 1, 3, 3, 3, 0, 3,
#        3, 0, 1, 2, 0, 3, 2, 0, 1, 3, 0, 0, 3, 2, 1, 2, 1, 3, 2, 0, 1, 2, 2,
#        1, 2, 0, 1, 3, 1, 2, 2, 0, 3, 0, 0, 1, 2, 1, 0, 0, 0, 3, 2, 1, 1, 1,
#        1, 3, 0, 1, 2, 3, 1, 2, 0, 1, 0, 0, 2, 0, 1, 2, 1, 1, 0, 3, 3, 2, 1,
#        2, 3, 3, 2, 3, 0, 3, 0, 3, 0, 2, 3, 0, 1, 3, 3, 3, 0, 1, 1, 3, 2, 3,
#        2, 0, 1, 2, 1, 3, 3, 2, 0, 1, 3, 3, 3, 3, 0, 2, 0, 3, 2, 2, 2, 0, 2,
#        0, 0, 3, 1, 3, 0, 2, 3, 0, 2, 0, 3, 3, 0, 3, 2, 2, 1, 2, 3, 1, 1, 3,
#        1, 1, 1, 1, 1, 0, 1, 2, 2, 3, 1, 0, 2, 2, 1, 0])

# %%
X[:,1].shape
# Out:
# (200,)

# %%
plt.scatter(x=X[:,0],y=X[:,1],cmap='rainbow')

# %%
#learning

# %%
from sklearn.cluster import  KMeans

# %%
kmeans=KMeans(n_clusters=10)

# %%
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=10, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ -4.95703389,   6.65452255],
#        [ -8.92965249,  -7.74388679],
#        [  5.10828057,   4.90813315],
#        [ -1.48722458,   1.8096295 ],
#        [  0.62410762,   5.30366491],
#        [ -6.3204094 ,   9.86379828],
#        [  3.92332853,   8.33708576],
#        [-10.35008901,  -4.63054116],
#        [ -2.29074575,   8.69960341],
#        [  1.56319372,   0.51379481]])

# %%
kmeans.labels_
# Out:
# array([5, 2, 3, 6, 6, 7, 6, 3, 6, 3, 5, 3, 6, 4, 5, 3, 2, 3, 7, 5, 7, 9, 4,
#        1, 0, 1, 1, 9, 6, 2, 8, 1, 2, 9, 3, 0, 7, 7, 1, 9, 1, 8, 8, 8, 3, 4,
#        0, 4, 1, 4, 9, 0, 2, 9, 1, 4, 4, 9, 0, 6, 1, 4, 7, 8, 6, 3, 7, 2, 6,
#        1, 6, 4, 7, 3, 1, 2, 6, 3, 5, 3, 4, 1, 6, 1, 9, 3, 3, 0, 4, 7, 1, 1,
#        7, 4, 4, 1, 6, 0, 1, 2, 3, 7, 4, 3, 4, 4, 7, 6, 1, 1, 2, 8, 0, 6, 1,
#        2, 8, 5, 4, 8, 4, 0, 3, 0, 3, 2, 5, 3, 1, 8, 0, 8, 9, 1, 7, 0, 2, 0,
#        6, 9, 1, 2, 7, 8, 8, 4, 4, 1, 0, 0, 8, 8, 3, 2, 9, 5, 4, 6, 6, 9, 6,
#        9, 3, 0, 7, 0, 3, 6, 8, 9, 6, 9, 0, 4, 4, 0, 6, 4, 1, 4, 8, 1, 1, 8,
#        7, 1, 7, 1, 1, 9, 7, 6, 6, 0, 1, 4, 6, 6, 7, 9], dtype=int32)

# %%
fig, (ax1,ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))

ax1.scatter(x=X[:,0],y=X[:,1],c=y)
ax2.scatter(x=X[:,0],y=X[:,1],c=kmeans.labels_)
